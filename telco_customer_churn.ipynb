# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

print("Libraries imported successfully!")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Libraries imported successfully!

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\admin
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\admin

# %%
import os

print(os.listdir(r"C:\Users\admin\OneDrive"))
# Out:
# ['.849C9593-D756-4E56-8D6E-42412F2A707B', 'Attachments', 'COA All UNIT.docx', 'COA QUESTION BANK-1-1.docx', 'Desktop', 'desktop.ini', 'Getting started with OneDrive.pdf', 'Scans', '图片', '文档']

# %%
import os

print(os.listdir(r"C:\Users\admin\OneDrive\Desktop"))
# Out:
# ['Antigravity.lnk', 'CampusMate', 'Case-Study-1-Telco-Customer-Churn', 'desktop.ini', 'Medical Assistant Ai Chatbot', 'medical Assistant Ai CHatbot -Final work', 'Medical Assistant Ai Chatbot.zip', 'Microsoft Edge.lnk', 'Telegram.lnk', 'TeraBox.lnk', 'Visual Studio Code.lnk']

# %%
import os

os.chdir(r"C:\Users\admin\OneDrive\Desktop\Case-Study-1-Telco-Customer-Churn")

print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\admin\OneDrive\Desktop\Case-Study-1-Telco-Customer-Churn
# ['WA_Fn-UseC_-Telco-Customer-Churn.csv']

# %%
import os

path = r"C:\Users\admin\Downloads\WA_Fn-UseC_-Telco-Customer-Churn.csv"

print("Exists:", os.path.exists(path))
print("Is file:", os.path.isfile(path))
# Out:
# Exists: True
# Is file: False

# %%
import os

print(os.listdir(r"C:\ml project"))
# Out:
# ['WA_Fn-UseC_-Telco-Customer-Churn.csv']

# %%
import os

path = r"C:\ml project\WA_Fn-UseC_-Telco-Customer-Churn.csv"

print("File exists:", os.path.exists(path))
print("File size:", os.path.getsize(path))
# Out:
# File exists: True
# File size: 0

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\admin
# ...

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn (1).csv")

print("Dataset loaded successfully!")
print("Dataset shape:", df.shape)

df.head()
# Out:
# Dataset loaded successfully!
# Dataset shape: (7043, 21)
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
print("Rows and Columns:", df.shape)

print("\nColumn Names:")
print(df.columns.tolist())
# Out:
# Rows and Columns: (7043, 21)
#
# Column Names:
# ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']

# %%
print("Missing values in each column:\n")
print(df.isnull().sum())
# Out:
# Missing values in each column:
#
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
print("Churn Distribution:")
print(df["Churn"].value_counts())

print("\nChurn Percentage:")
print(df["Churn"].value_counts(normalize=True) * 100)
# Out:
# Churn Distribution:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
#
# Churn Percentage:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
print("Churn Distribution:")
print(df["Churn"].value_counts())

print("\nChurn Percentage:")
print(df["Churn"].value_counts(normalize=True) * 100)
# Out:
# Churn Distribution:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
#
# Churn Percentage:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
print("BUSINESS PROBLEM CLASSIFICATION")
print("--------------------------------")
print("Problem Type: Classification")
print("Target Variable: Churn")
print("Objective: Predict whether a customer will churn (Yes) or stay (No).")
print("Success Metric: F1-Score")
# Out:
# BUSINESS PROBLEM CLASSIFICATION
# --------------------------------
# Problem Type: Classification
# Target Variable: Churn
# Objective: Predict whether a customer will churn (Yes) or stay (No).
# Success Metric: F1-Score

# %% [markdown]
# # Case Study 1: Business Problem Classification
#
# ## Dataset
# Telco Customer Churn Dataset
#
# ## Case Study 1 – Telecom Customer Churn
# - **Business Problem:** Predict whether a customer will churn.
# - **Problem Type:** Binary Classification
# - **Target Variable:** Churn
# - **Classes:** Yes / No
# - **Success Metric:** F1-Score
#
# ## Five Real-World Business Problems
#
# | # | Business Case | Problem Type | Target / Goal | Success Metric |
# |---|---|---|---|---|
# | 1 | Telecom Customer Churn | Classification | Predict customer churn (Yes/No) | F1-Score |
# | 2 | House Price Prediction | Regression | Predict house selling price | RMSE |
# | 3 | Customer Segmentation | Clustering | Group customers by similar behavior | Silhouette Score |
# | 4 | Email Spam Detection | Classification | Predict Spam/Not Spam | Precision / Recall |
# | 5 | Sales Revenue Prediction | Regression | Predict future sales revenue | MAE |
#
# ## Conclusion
#
# The Telco Customer Churn problem is a **binary classification problem** because the target variable `Churn` has two possible outcomes: **Yes** and **No**.
#
# The primary success metric is **F1-Score**, as the business needs a balance between identifying customers who will churn and avoiding unnecessary retention efforts.

# %%
import os

print(os.path.abspath("telco_customer_churn.ipynb"))
# Out:
# C:\Users\admin\telco_customer_churn.ipynb
